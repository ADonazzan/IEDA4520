# %%
from polygon import RESTClient
import datetime as dt
import pandas as pd

polygonAPIkey = 'I9NEtqmIc8HkoeIvUB27V8DR1MC68wUu'

#create client and authenticate w/ API key // rate limit 5 requests per min
client = RESTClient(polygonAPIkey) # api_key is used

# %%
contractNames = []
for c in client.list_options_contracts(underlying_ticker = 'GOOG', limit = 100):
    contractNames.append(c)
print(contractNames)
# Out:
# [OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2023-11-10', primary_exchange='BATO', shares_per_contract=100, strike_price=70, ticker='O:GOOG231110C00070000', underlying_ticker='GOOG'), OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2023-11-10', primary_exchange='BATO', shares_per_contract=100, strike_price=75, ticker='O:GOOG231110C00075000', underlying_ticker='GOOG'), OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2023-11-10', primary_exchange='BATO', shares_per_contract=100, strike_price=80, ticker='O:GOOG231110C00080000', underlying_ticker='GOOG'), OptionsContract(additional_underlyings=None, cfi='OCASPS', contract_type='call', correction=None, exercise_style='american', expiration_date='2023-11-10',
# ...

# %% [markdown]
# Get further info: https://www.youtube.com/watch?v=87O9qxfMJ-g
